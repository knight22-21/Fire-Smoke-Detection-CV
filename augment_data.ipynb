# %%
# !pip install albumentations --user
# Out:
# Collecting albumentations
#   Using cached albumentations-2.0.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\krish\anaconda3\lib\site-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\krish\anaconda3\lib\site-packages (from albumentations) (1.11.4)
# Requirement already satisfied: PyYAML in c:\users\krish\anaconda3\lib\site-packages (from albumentations) (6.0.1)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\krish\anaconda3\lib\site-packages (from albumentations) (2.10.3)
# Collecting albucore==0.0.24 (from albumentations)
#   Using cached albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\krish\anaconda3\lib\site-packages (from albucore==0.0.24->albumentations) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\krish\anaconda3\lib\site-packages (from albucore==0.0.24->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krish\anaconda3\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\krish\anaconda3\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\krish\anaconda3\lib\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Using cached albumentations-2.0.6-py3-none-any.whl (332 kB)
# Using cached albucore-0.0.24-py3-none-any.whl (15 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
# Installing collected packages: opencv-python-headless, albucore, albumentations
# Successfully installed albucore-0.0.24 albumentations-2.0.6 opencv-python-headless-4.11.0.86

# %%
import os
import cv2
import albumentations as A
from tqdm.notebook import tqdm
import  gc

# %%
# === PATHS ===
BASE_PATH = "dataset/train"
image_dir = os.path.join(BASE_PATH, "images")
label_dir = os.path.join(BASE_PATH, "labels")
aug_image_dir = os.path.join(BASE_PATH, "images_aug")
aug_label_dir = os.path.join(BASE_PATH, "labels_aug")

# Create output directories
os.makedirs(aug_image_dir, exist_ok=True)
os.makedirs(aug_label_dir, exist_ok=True)

# === AUGMENTATION PIPELINE ===
transform = A.Compose([
    A.Resize(640, 640, p=1.0),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels'], check_each_transform=False))

# === UTILITY FUNCTIONS ===

def read_label(file_path):
    with open(file_path, 'r') as f:
        lines = f.readlines()
    boxes, labels = [], []
    for line in lines:
        parts = line.strip().split()
        if len(parts) != 5:
            continue  # skip malformed lines
        labels.append(int(parts[0]))
        boxes.append([float(x) for x in parts[1:]])
    return boxes, labels

def write_label(file_path, labels, boxes):
    with open(file_path, 'w') as f:
        for label, box in zip(labels, boxes):
            f.write(f"{label} {' '.join(map(lambda x: str(round(x, 6)), box))}\n")

# === MAIN LOOP ===

files = sorted(os.listdir(image_dir))[:]

for filename in tqdm(files):
    if not filename.lower().endswith((".jpg", ".jpeg", ".png")):
        continue

    image_path = os.path.join(image_dir, filename)
    label_path = os.path.join(label_dir, os.path.splitext(filename)[0] + ".txt")

    if not os.path.exists(label_path):
        print(f"Missing label for {filename}, creating empty label.")
        open(label_path, 'a').close()  # create empty label

    image = cv2.imread(image_path)
    if image is None:
        print(f"Unreadable image: {filename}, skipping.")
        continue

    boxes, labels = read_label(label_path)

    # Apply transformation 
    try:
        transformed = transform(image=image, bboxes=boxes, class_labels=labels)
    except Exception as e:
        print(f"Error during transform on {filename}: {e}")
        continue

    aug_img = transformed['image']
    aug_boxes = transformed['bboxes']
    aug_labels = transformed['class_labels']

    # Clip bounding boxes to [0, 1]
    aug_boxes = [[min(max(coord, 0.0), 1.0) for coord in box] for box in aug_boxes]

    # Save augmented image
    new_img_name = f"{os.path.splitext(filename)[0]}_aug.jpg"
    cv2.imwrite(os.path.join(aug_image_dir, new_img_name), aug_img)

    # Save label 
    new_lbl_name = new_img_name.replace(".jpg", ".txt")
    write_label(os.path.join(aug_label_dir, new_lbl_name), aug_labels, aug_boxes)

    # Memory cleanup
    del image, aug_img
    gc.collect()
# Out:
#   0%|          | 0/14122 [00:00<?, ?it/s]
# Error during transform on AoF04522.jpg: Expected x_max for bbox [0.9568835  0.22764227 1.0007564  0.40487805 1.        ] to be in the range [0.0, 1.0], got 1.0007563829421997.
# Error during transform on AoF04568.jpg: Expected x_max for bbox [0.95510834 0.2234957  1.000774   0.265043   1.        ] to be in the range [0.0, 1.0], got 1.0007740259170532.
# Error during transform on AoF04627.jpg: Expected x_min for bbox [-0.0015625   0.2888889   0.053125    0.39444444  1.        ] to be in the range [0.0, 1.0], got -0.0015625003725290298.
# Error during transform on AoF04663.jpg: Expected x_min for bbox [-7.8125298e-04  2.7638888e-01  6.6406250e-02  4.0833336e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812529802322388.
# Error during transform on AoF04664.jpg: Expected x_min for bbox [-0.0015625   0.28333333  0.06796875  0.4         1.        ] to be in the range [0.0, 1.0], got -0.0015624985098838806.
# Error during transform on AoF04687.jpg: Expected x_min for bbox [-7.8124925e-04  2.7638888e-01  3.4375001e-02  3.6250001e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812492549419403.
# Error during transform on AoF04689.jpg: Expected x_min for bbox [-7.8125112e-04  2.7361113e-01  4.1406251e-02  3.8333333e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812511175870895.
# Error during transform on AoF04690.jpg: Expected x_min for bbox [-7.8125112e-04  2.8888890e-01  5.2343749e-02  3.9444444e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812511175870895.
# Error during transform on AoF04695.jpg: Expected x_min for bbox [-7.8124925e-04  2.9027778e-01  4.7656249e-02  3.9027780e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812492549419403.
# Error during transform on AoF04696.jpg: Expected x_min for bbox [-7.8124925e-04  2.9027778e-01  4.7656249e-02  3.9027780e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812492549419403.
# Error during transform on AoF04723.jpg: Expected x_min for bbox [-0.0015625   0.2847222   0.05546875  0.39722222  1.        ] to be in the range [0.0, 1.0], got -0.0015625003725290298.
# Error during transform on AoF04750.jpg: Expected x_min for bbox [-7.8124925e-04  2.9166669e-01  4.7656249e-02  3.8888890e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812492549419403.
# Error during transform on AoF04761.jpg: Expected x_min for bbox [-7.812511e-04  2.916667e-01  4.843750e-02  3.888889e-01  1.000000e+00] to be in the range [0.0, 1.0], got -0.0007812511175870895.
# Error during transform on AoF04763.jpg: Expected x_min for bbox [-7.8125112e-04  2.8888890e-01  4.9218751e-02  3.9027777e-01
#   1.0000000e+00] to be in the range [0.0, 1.0], got -0.0007812511175870895.
# Error during transform on AoF04798.jpg: Expected x_min for bbox [-0.0015625   0.27916667  0.0734375   0.40277776  1.        ] to be in the range [0.0, 1.0], got -0.001562502235174179.
# Error during transform on AoF04854.jpg: Expected x_max for bbox [0.9742188  0.4        1.0007813  0.45416668 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04856.jpg: Expected x_max for bbox [0.5945313 0.3625    1.0117188 0.5847222 1.       ] to be in the range [0.0, 1.0], got 1.01171875.
# Error during transform on AoF04857.jpg: Expected x_max for bbox [0.62031245 0.04583335 1.015625   0.50972223 0.        ] to be in the range [0.0, 1.0], got 1.015625.
# Error during transform on AoF04858.jpg: Expected x_max for bbox [0.97578126 0.36944446 1.0007813  0.45694444 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04861.jpg: Expected x_max for bbox [0.61328125 0.30416667 1.0125     0.56527776 1.        ] to be in the range [0.0, 1.0], got 1.0125000476837158.
# Error during transform on AoF04869.jpg: Expected x_max for bbox [0.93671876 0.3027778  1.0007813  0.45833334 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04871.jpg: Expected x_max for bbox [0.94140625 0.31527779 1.0007813  0.46666667 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04873.jpg: Expected x_max for bbox [0.94375    0.31666666 1.0015625  0.47083336 1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on AoF04875.jpg: Expected x_max for bbox [0.94375   0.3013889 1.0015625 0.4486111 1.       ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on AoF04963.jpg: Expected x_max for bbox [0.9789062 0.4625    1.0007812 0.5083333 1.       ] to be in the range [0.0, 1.0], got 1.0007811784744263.
# Error during transform on AoF04964.jpg: Expected x_max for bbox [0.9796875  0.46111113 1.0007813  0.50972223 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04966.jpg: Expected x_max for bbox [0.97812504 0.46111113 1.0007813  0.5083333  1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04967.jpg: Expected x_max for bbox [0.9796875 0.4611111 1.0007813 0.5111111 1.       ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04968.jpg: Expected x_max for bbox [0.9765625  0.46666667 1.0007813  0.5125     1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04970.jpg: Expected x_max for bbox [0.9765625  0.46805558 1.0007813  0.51111114 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04971.jpg: Expected x_max for bbox [0.97499996 0.47083336 1.0007812  0.55       1.        ] to be in the range [0.0, 1.0], got 1.0007811784744263.
# Error during transform on AoF04979.jpg: Expected x_max for bbox [0.97265625 0.47916666 1.0007813  0.54444444 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04989.jpg: Expected x_max for bbox [0.97499996 0.47916666 1.0007812  0.54444444 1.        ] to be in the range [0.0, 1.0], got 1.0007811784744263.
# Error during transform on AoF04991.jpg: Expected x_max for bbox [0.97499996 0.4791667  1.0007812  0.5486111  1.        ] to be in the range [0.0, 1.0], got 1.0007811784744263.
# Error during transform on AoF04992.jpg: Expected x_max for bbox [0.9742188  0.48194444 1.0007813  0.54583335 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF04997.jpg: Expected x_max for bbox [0.9710937  0.48472223 1.0007812  0.54305553 1.        ] to be in the range [0.0, 1.0], got 1.0007811784744263.
# Error during transform on AoF05005.jpg: Expected x_max for bbox [0.97031254 0.48055553 1.0007813  0.54444444 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on AoF05311.jpg: Expected y_min for bbox [ 0.15234375 -0.00138889  0.2203125   0.1125      0.        ] to be in the range [0.0, 1.0], got -0.00138888880610466.
# Error during transform on AoF05352.jpg: Expected y_min for bbox [ 0.1484375  -0.00138889  0.2109375   0.1111111   0.        ] to be in the range [0.0, 1.0], got -0.00138888880610466.
# Error during transform on AoF05411.jpg: Expected y_min for bbox [ 0.12968749 -0.00138889  0.23046875  0.1111111   0.        ] to be in the range [0.0, 1.0], got -0.00138888880610466.
# Error during transform on AoF05412.jpg: Expected y_min for bbox [ 0.12890625 -0.00138889  0.228125    0.1125      0.        ] to be in the range [0.0, 1.0], got -0.00138888880610466.
# Error during transform on AoF05413.jpg: Expected y_min for bbox [ 0.13046876 -0.00138889  0.21171874  0.10972223  0.        ] to be in the range [0.0, 1.0], got -0.00138888880610466.
# Error during transform on AoF05470.jpg: x_max is less than or equal to x_min for bbox [0.55859375 0.46666667 0.55859375 0.46666667 0.        ].
# Error during transform on AoF05874.jpg: Expected x_max for bbox [0.68098956 0.02546297 1.001302   0.4328704  0.        ] to be in the range [0.0, 1.0], got 1.0013020038604736.
# Error during transform on AoF06155.jpg: x_max is less than or equal to x_min for bbox [0.8125 0.3375 0.8125 0.3375 0.    ].
# Error during transform on AoF06348.jpg: x_max is less than or equal to x_min for bbox [0.753125   0.25833333 0.753125   0.25833333 0.        ].
# Error during transform on AoF06439.jpg: x_max is less than or equal to x_min for bbox [0.7125 0.275  0.7125 0.275  0.    ].
# Error during transform on AoF06456.jpg: x_max is less than or equal to x_min for bbox [0.14765625 0.4375     0.14765625 0.4375     0.        ].
# Error during transform on PublicDataset00056.jpg: x_max is less than or equal to x_min for bbox [0.3296875  0.81388885 0.3296875  0.81666666 1.        ].
# Error during transform on WEB03821.jpg: Expected x_max for bbox [0.70703125 0.3041667  1.0015625  0.97638893 1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB04008.jpg: Expected y_max for bbox [0.15955055 0.962      0.3022472  1.002      1.        ] to be in the range [0.0, 1.0], got 1.0019999742507935.
# Error during transform on WEB04012.jpg: Expected y_max for bbox [0.0129717  0.46041664 0.4716981  1.0041666  0.        ] to be in the range [0.0, 1.0], got 1.004166603088379.
# Error during transform on WEB04112.jpg: Expected y_max for bbox [0.003125   0.51666665 0.28359377 1.0013889  1.        ] to be in the range [0.0, 1.0], got 1.0013889074325562.
# Error during transform on WEB04185.jpg: Expected y_max for bbox [0.00788643 0.68571424 0.21293375 1.002381   1.        ] to be in the range [0.0, 1.0], got 1.0023809671401978.
# Error during transform on WEB04188.jpg: Expected y_max for bbox [0.00663128 0.82004553 0.6405835  1.0022779  1.        ] to be in the range [0.0, 1.0], got 1.0022778511047363.
# Error during transform on WEB04193.jpg: Expected y_max for bbox [0.9080645 0.637883  0.9983871 1.0027854 1.       ] to be in the range [0.0, 1.0], got 1.0027854442596436.
# Error during transform on WEB04195.jpg: Expected y_max for bbox [0.01666667 0.7416667  0.14545454 1.0027778  1.        ] to be in the range [0.0, 1.0], got 1.0027778148651123.
# Error during transform on WEB04243.jpg: x_max is less than or equal to x_min for bbox [0.2685547  0.41666666 0.2685547  0.41666666 1.        ].
# Error during transform on WEB04331.jpg: Expected x_max for bbox [0.88646287 0.39812645 1.0014555  0.763466   0.        ] to be in the range [0.0, 1.0], got 1.001455545425415.
# Error during transform on WEB04410.jpg: Expected x_max for bbox [0.87890625 0.2851852  1.0009766  0.40740743 1.        ] to be in the range [0.0, 1.0], got 1.0009765625.
# Error during transform on WEB04420.jpg: Expected x_max for bbox [0.9384615  0.01906779 1.0017093  0.10381356 1.        ] to be in the range [0.0, 1.0], got 1.0017093420028687.
# Error during transform on WEB04435.jpg: Expected x_max for bbox [0.6425     0.56300265 1.00375    0.69437    1.        ] to be in the range [0.0, 1.0], got 1.003749966621399.
# Error during transform on WEB04450.jpg: Expected y_max for bbox [0.17968749 0.7869318  0.61875    1.0028409  1.        ] to be in the range [0.0, 1.0], got 1.0028408765792847.
# Error during transform on WEB04527.jpg: x_max is less than or equal to x_min for bbox [0.553      0.73309606 0.553      0.73309606 1.        ].
# Error during transform on WEB04742.jpg: x_max is less than or equal to x_min for bbox [0.3875     0.49166667 0.3875     0.49166667 1.        ].
# Error during transform on WEB04849.jpg: x_max is less than or equal to x_min for bbox [0.1484375  0.42222223 0.1484375  0.42222223 1.        ].
# Error during transform on WEB04983.jpg: Expected x_min for bbox [-0.003125    0.          0.1296875   0.41944444  0.        ] to be in the range [0.0, 1.0], got -0.0031249970197677612.
# Error during transform on WEB05038.jpg: Expected x_min for bbox [-0.00156251  0.36079544  0.4125      0.6619318   1.        ] to be in the range [0.0, 1.0], got -0.0015625059604644775.
# Error during transform on WEB05050.jpg: Expected x_min for bbox [-0.01093751  0.00277776  0.9890625   0.6611111   0.        ] to be in the range [0.0, 1.0], got -0.010937511920928955.
# Error during transform on WEB05084.jpg: Expected x_max for bbox [0.18124998 0.05277777 1.0015625  0.67777777 0.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05086.jpg: Expected x_max for bbox [0.7359375 0.7416667 1.009375  0.8111111 1.       ] to be in the range [0.0, 1.0], got 1.009374976158142.
# Error during transform on WEB05088.jpg: Expected y_max for bbox [0.76875    0.95694447 0.81953126 1.0013889  1.        ] to be in the range [0.0, 1.0], got 1.0013889074325562.
# Error during transform on WEB05092.jpg: Expected y_min for bbox [ 0.06562501 -0.00833333  0.98593754  0.8333333   0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05093.jpg: Expected y_min for bbox [ 0.01015627 -0.02222222  1.0101563   0.7361111   0.        ] to be in the range [0.0, 1.0], got -0.02222222089767456.
# Error during transform on WEB05096.jpg: Expected x_max for bbox [0.7984375  0.7416666  1.0078125  0.81666666 1.        ] to be in the range [0.0, 1.0], got 1.0078125.
# Error during transform on WEB05100.jpg: Expected x_max for bbox [0.9359375  0.6611111  1.0015625  0.82500005 1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05103.jpg: Expected x_max for bbox [0.9328125 0.6166667 1.003125  0.875     1.       ] to be in the range [0.0, 1.0], got 1.0031249523162842.
# Error during transform on WEB05107.jpg: Expected x_max for bbox [0.90468746 0.30833334 1.003125   0.51666665 1.        ] to be in the range [0.0, 1.0], got 1.0031249523162842.
# Error during transform on WEB05108.jpg: Expected y_min for bbox [ 0.04375002 -0.00277779  0.9765625   0.73888886  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05110.jpg: Expected x_max for bbox [0.934375   0.67777777 1.0015625  0.9        1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05111.jpg: Expected y_min for bbox [ 0.00312501 -0.01944444  1.003125    0.6888889   0.        ] to be in the range [0.0, 1.0], got -0.019444435834884644.
# Error during transform on WEB05112.jpg: Expected y_min for bbox [ 0.0546875  -0.04444447  0.953125    0.73888886  0.        ] to be in the range [0.0, 1.0], got -0.04444447159767151.
# Error during transform on WEB05114.jpg: Expected x_max for bbox [0.946875   0.73888886 1.0015625  0.8138889  1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05115.jpg: Expected y_min for bbox [ 0.04374999 -0.00277779  0.9875      0.73333335  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05117.jpg: Expected y_min for bbox [ 0.05312502 -0.00277779  0.9828125   0.67222226  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05118.jpg: Expected y_min for bbox [ 0.01249999 -0.01944447  0.996875    0.7583333   0.        ] to be in the range [0.0, 1.0], got -0.01944446563720703.
# Error during transform on WEB05124.jpg: Expected y_min for bbox [ 0.         -0.00833333  0.271875    0.42222223  0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05126.jpg: Expected x_min for bbox [-0.00156251  0.01111111  0.98125005  0.5611111   0.        ] to be in the range [0.0, 1.0], got -0.0015625059604644775.
# Error during transform on WEB05129.jpg: Expected x_max for bbox [0.85625    0.3333333  1.0015625  0.45555556 1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05130.jpg: Expected x_max for bbox [0.6       0.5083333 1.009375  0.6277778 1.       ] to be in the range [0.0, 1.0], got 1.009374976158142.
# Error during transform on WEB05131.jpg: Expected x_max for bbox [0.56875    0.43611115 1.0109375  0.5861111  1.        ] to be in the range [0.0, 1.0], got 1.0109374523162842.
# Error during transform on WEB05145.jpg: Expected y_min for bbox [ 0.35312498 -0.00833333  0.6484375   0.41944444  0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05152.jpg: Expected y_min for bbox [ 0.36949688 -0.00555554  0.7688679   0.73055553  0.        ] to be in the range [0.0, 1.0], got -0.005555540323257446.
# Error during transform on WEB05154.jpg: Expected x_max for bbox [7.8123808e-04 1.6666651e-02 1.0007813e+00 6.6944444e-01 0.0000000e+00] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on WEB05155.jpg: Expected y_min for bbox [ 0.45937502 -0.01111111  0.8265625   0.375       0.        ] to be in the range [0.0, 1.0], got -0.01111111044883728.
# Error during transform on WEB05157.jpg: Expected y_min for bbox [ 0.61406255 -0.01666667  0.86875     0.41388887  0.        ] to be in the range [0.0, 1.0], got -0.01666666567325592.
# Error during transform on WEB05158.jpg: Expected y_min for bbox [ 0.45       -0.00833334  0.87343746  0.38333333  0.        ] to be in the range [0.0, 1.0], got -0.008333340287208557.
# Error during transform on WEB05160.jpg: Expected x_max for bbox [0.01249999 0.02777776 1.0125     0.6944444  0.        ] to be in the range [0.0, 1.0], got 1.0125000476837158.
# Error during transform on WEB05162.jpg: Expected x_min for bbox [-0.00312501 -0.08472222  0.996875    0.9152778   0.        ] to be in the range [0.0, 1.0], got -0.003125011920928955.
# Error during transform on WEB05164.jpg: Expected x_min for bbox [-0.02500001 -0.00555557  0.70000005  0.68333334  0.        ] to be in the range [0.0, 1.0], got -0.025000005960464478.
# Error during transform on WEB05165.jpg: Expected x_min for bbox [-0.003125    0.34444445  0.1734375   0.4583333   1.        ] to be in the range [0.0, 1.0], got -0.003125004470348358.
# Error during transform on WEB05167.jpg: Expected y_min for bbox [ 0.8703125  -0.00277779  1.003125    0.41944444  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05174.jpg: Expected y_min for bbox [ 0.02499998 -0.00555556  0.671875    0.4222222   0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB05176.jpg: Expected x_min for bbox [-0.0046875   0.30833334  0.171875    0.4361111   1.        ] to be in the range [0.0, 1.0], got -0.004687502980232239.
# Error during transform on WEB05188.jpg: Expected x_min for bbox [-0.0015625   0.38055557  0.096875    0.49166667  1.        ] to be in the range [0.0, 1.0], got -0.001562502235174179.
# Error during transform on WEB05192.jpg: Expected x_min for bbox [-0.0015625   0.30277777  0.1140625   0.41111112  1.        ] to be in the range [0.0, 1.0], got -0.001562502235174179.
# Error during transform on WEB05195.jpg: Expected y_max for bbox [0.534375  0.8       0.809375  1.0027778 1.       ] to be in the range [0.0, 1.0], got 1.0027778148651123.
# Error during transform on WEB05196.jpg: Expected y_max for bbox [0.38125002 0.7972222  0.6140625  1.0027778  1.        ] to be in the range [0.0, 1.0], got 1.0027778148651123.
# Error during transform on WEB05201.jpg: Expected y_min for bbox [ 0.04843751 -0.00277779  0.77812505  0.5555556   0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05206.jpg: Expected x_min for bbox [-0.0015625   0.35277778  0.06875     0.46388888  1.        ] to be in the range [0.0, 1.0], got -0.0015624985098838806.
# Error during transform on WEB05212.jpg: Expected x_max for bbox [0.72812504 0.24444444 1.0031251  0.63055557 1.        ] to be in the range [0.0, 1.0], got 1.0031250715255737.
# Error during transform on WEB05215.jpg: Expected y_min for bbox [ 0.19999999 -0.01666667  0.6453125   0.40555555  0.        ] to be in the range [0.0, 1.0], got -0.01666666567325592.
# Error during transform on WEB05217.jpg: Expected y_min for bbox [ 0.5765625  -0.00833334  0.8203125   0.37222224  0.        ] to be in the range [0.0, 1.0], got -0.008333340287208557.
# Error during transform on WEB05219.jpg: Expected y_min for bbox [ 0.5015625  -0.00277777  0.709375    0.39166665  0.        ] to be in the range [0.0, 1.0], got -0.002777770161628723.
# Error during transform on WEB05220.jpg: Expected y_min for bbox [ 0.096875   -0.01944444  0.44687498  0.375       0.        ] to be in the range [0.0, 1.0], got -0.019444435834884644.
# Error during transform on WEB05223.jpg: Expected y_min for bbox [ 0.2265625  -0.00555556  0.45        0.41111112  0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB05224.jpg: Expected y_min for bbox [ 0.0859375  -0.00555556  0.4453125   0.35555553  0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB05227.jpg: Expected y_min for bbox [ 0.15       -0.00833334  0.865625    0.42777777  0.        ] to be in the range [0.0, 1.0], got -0.008333340287208557.
# Error during transform on WEB05228.jpg: Expected y_min for bbox [ 0.3359375  -0.01111111  0.5265625   0.3861111   0.        ] to be in the range [0.0, 1.0], got -0.01111111044883728.
# Error during transform on WEB05229.jpg: Expected y_min for bbox [ 0.02187501 -0.00833334  0.5078125   0.38333333  0.        ] to be in the range [0.0, 1.0], got -0.008333340287208557.
# Error during transform on WEB05231.jpg: Expected y_min for bbox [ 0.1203125  -0.00555557  0.540625    0.375       0.        ] to be in the range [0.0, 1.0], got -0.005555570125579834.
# Error during transform on WEB05232.jpg: Expected y_min for bbox [ 0.13749999 -0.00555556  0.53125     0.35555553  0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB05233.jpg: Expected y_min for bbox [ 0.03593749 -0.00277779  0.5125      0.37222221  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05236.jpg: Expected y_min for bbox [ 0.01249999 -0.01111111  0.5578125   0.51388884  0.        ] to be in the range [0.0, 1.0], got -0.01111111044883728.
# Error during transform on WEB05237.jpg: Expected y_min for bbox [ 0.4390625  -0.00833333  0.87968755  0.4         0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05238.jpg: Expected x_min for bbox [-0.0125      0.35277778  0.378125    0.5277778   1.        ] to be in the range [0.0, 1.0], got -0.012500002980232239.
# Error during transform on WEB05243.jpg: Expected y_min for bbox [ 0.3515625  -0.00833333  0.80625     0.39722222  0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05244.jpg: Expected y_min for bbox [ 0.09687498 -0.00277777  0.771875    0.36666667  0.        ] to be in the range [0.0, 1.0], got -0.002777770161628723.
# Error during transform on WEB05246.jpg: Expected y_min for bbox [ 0.3453125  -0.00277779  0.81718755  0.37777779  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB05254.jpg: Expected y_min for bbox [ 0.32187498 -0.00833333  0.9921875   0.7277778   0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05255.jpg: Expected x_min for bbox [-0.003125    0.23888889  0.109375    0.35833332  1.        ] to be in the range [0.0, 1.0], got -0.0031249970197677612.
# Error during transform on WEB05256.jpg: Expected x_min for bbox [-0.003125    0.32222223  0.0671875   0.40555555  1.        ] to be in the range [0.0, 1.0], got -0.0031250007450580597.
# Error during transform on WEB05257.jpg: Expected x_min for bbox [-0.00156249 -0.01111111  0.3625      0.38333333  0.        ] to be in the range [0.0, 1.0], got -0.0015624910593032837.
# Error during transform on WEB05259.jpg: Expected y_min for bbox [ 0.0046875  -0.00277777  0.29531252  0.36666667  0.        ] to be in the range [0.0, 1.0], got -0.002777770161628723.
# Error during transform on WEB05262.jpg: Expected y_min for bbox [ 0.00624999 -0.01111111  0.4125      0.39444444  0.        ] to be in the range [0.0, 1.0], got -0.01111111044883728.
# Error during transform on WEB05263.jpg: Expected y_min for bbox [ 0.00937501 -0.00833333  0.4078125   0.3611111   0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05265.jpg: Expected x_max for bbox [0.6546875  0.39444447 1.0015625  0.60833335 1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05266.jpg: Expected x_min for bbox [-0.0015625   0.23888889  0.0875      0.35        1.        ] to be in the range [0.0, 1.0], got -0.0015624985098838806.
# Error during transform on WEB05267.jpg: Expected x_max for bbox [0.7171875 0.4277778 1.009375  0.8972223 1.       ] to be in the range [0.0, 1.0], got 1.009374976158142.
# Error during transform on WEB05271.jpg: Expected y_min for bbox [ 0.02187499 -0.00833333  0.571875    0.71944445  0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB05276.jpg: Expected y_min for bbox [ 0.03281251 -0.07499999  0.99687505  0.78055555  0.        ] to be in the range [0.0, 1.0], got -0.07499998807907104.
# Error during transform on WEB05279.jpg: Expected x_min for bbox [-0.003125    0.18888888  0.08437499  0.51111114  1.        ] to be in the range [0.0, 1.0], got -0.0031250007450580597.
# Error during transform on WEB05281.jpg: Expected x_min for bbox [-0.0015625   0.28055555  0.0328125   0.35833335  1.        ] to be in the range [0.0, 1.0], got -0.0015625003725290298.
# Error during transform on WEB05285.jpg: Expected x_min for bbox [-0.0015625   0.4027778   0.125       0.60555553  1.        ] to be in the range [0.0, 1.0], got -0.001562502235174179.
# Error during transform on WEB05287.jpg: Expected y_min for bbox [ 0.4796875  -0.0138889   0.76875     0.40833333  0.        ] to be in the range [0.0, 1.0], got -0.013888895511627197.
# Error during transform on WEB05289.jpg: Expected x_min for bbox [-0.0109375   0.19722222  0.2703125   0.51666665  1.        ] to be in the range [0.0, 1.0], got -0.010937497019767761.
# Error during transform on WEB05293.jpg: Expected x_max for bbox [0.809375  0.3       1.0046875 0.6583333 1.       ] to be in the range [0.0, 1.0], got 1.0046875476837158.
# Error during transform on WEB05295.jpg: Expected x_min for bbox [-0.003125    0.14444444  0.2421875   0.7166667   1.        ] to be in the range [0.0, 1.0], got -0.0031249970197677612.
# Error during transform on WEB05297.jpg: Expected x_max for bbox [0.8265625  0.225      1.00625    0.67222226 1.        ] to be in the range [0.0, 1.0], got 1.006250023841858.
# Error during transform on WEB05299.jpg: Expected x_min for bbox [-0.0109375   0.6611111   0.27187502  0.8333334   1.        ] to be in the range [0.0, 1.0], got -0.010937497019767761.
# Error during transform on WEB05300.jpg: Expected x_max for bbox [0.70624995 0.30277777 1.00625    0.6944445  1.        ] to be in the range [0.0, 1.0], got 1.006250023841858.
# Error during transform on WEB05304.jpg: Expected y_min for bbox [ 0.11093748 -0.02556819  0.9234375   0.75        0.        ] to be in the range [0.0, 1.0], got -0.02556818723678589.
# Error during transform on WEB05305.jpg: Expected x_max for bbox [0.5875     0.36079544 1.0015625  0.6619318  1.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB05307.jpg: Expected x_max for bbox [0.2843137  0.11388887 1.0441177  0.44722223 1.        ] to be in the range [0.0, 1.0], got 1.0441176891326904.
# Error during transform on WEB05308.jpg: Expected x_max for bbox [0.00735295 0.07777777 1.007353   0.4611111  1.        ] to be in the range [0.0, 1.0], got 1.0073529481887817.
# Error during transform on WEB05315.jpg: Expected x_min for bbox [-0.00546876  0.00833333  0.9945313   0.64444447  0.        ] to be in the range [0.0, 1.0], got -0.0054687559604644775.
# Error during transform on WEB05316.jpg: Expected x_min for bbox [-0.0015625   0.55277777  0.0984375   0.7861111   1.        ] to be in the range [0.0, 1.0], got -0.001562502235174179.
# Error during transform on WEB05317.jpg: Expected x_min for bbox [-0.01328126  0.00555557  0.9867188   0.65555555  0.        ] to be in the range [0.0, 1.0], got -0.013281255960464478.
# Error during transform on WEB05318.jpg: Expected x_max for bbox [0.01093751 0.00277776 1.0109375  0.6611111  0.        ] to be in the range [0.0, 1.0], got 1.0109374523162842.
# Error during transform on WEB05328.jpg: Expected y_min for bbox [ 0.34687498 -0.01420455  0.646875    0.45170456  0.        ] to be in the range [0.0, 1.0], got -0.014204546809196472.
# Error during transform on WEB05331.jpg: Expected y_min for bbox [ 0.34375    -0.00568181  0.6484375   0.4431818   0.        ] to be in the range [0.0, 1.0], got -0.005681812763214111.
# Error during transform on WEB05333.jpg: Expected y_min for bbox [ 0.34062502 -0.00852272  0.65        0.4431818   0.        ] to be in the range [0.0, 1.0], got -0.008522719144821167.
# Error during transform on WEB05343.jpg: Expected y_min for bbox [ 0.334375   -0.00852273  0.65156245  0.42897725  0.        ] to be in the range [0.0, 1.0], got -0.00852273404598236.
# Error during transform on WEB05348.jpg: Expected x_min for bbox [-0.0046875   0.40277776  0.11562499  0.4888889   1.        ] to be in the range [0.0, 1.0], got -0.00468749925494194.
# Error during transform on WEB05355.jpg: Expected y_min for bbox [ 0.05940592 -0.03055558  0.6138614   0.8777778   1.        ] to be in the range [0.0, 1.0], got -0.03055557608604431.
# Error during transform on WEB05356.jpg: Expected y_min for bbox [ 0.05445543 -0.03055558  0.6089109   0.89444447  1.        ] to be in the range [0.0, 1.0], got -0.03055557608604431.
# Error during transform on WEB05358.jpg: Expected y_min for bbox [ 0.13366336 -0.03055555  0.6980198   0.8833333   1.        ] to be in the range [0.0, 1.0], got -0.030555546283721924.
# Error during transform on WEB05360.jpg: Expected x_min for bbox [-0.00624999  0.15        0.99375     0.6805556   1.        ] to be in the range [0.0, 1.0], got -0.0062499940395355225.
# Error during transform on WEB05362.jpg: Expected x_min for bbox [-0.05312499  0.02500001  0.8890625   0.6666666   0.        ] to be in the range [0.0, 1.0], got -0.05312499403953552.
# Error during transform on WEB05363.jpg: Expected x_min for bbox [-0.01093751  0.05833334  0.9890625   0.625       0.        ] to be in the range [0.0, 1.0], got -0.010937511920928955.
# Error during transform on WEB05537.jpg: Expected x_max for bbox [0.840625  0.5875    1.0007813 0.6541667 1.       ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on WEB05757.jpg: Expected y_max for bbox [0.23906249 0.75284094 0.34375    1.002841   1.        ] to be in the range [0.0, 1.0], got 1.0028409957885742.
# Error during transform on WEB05882.jpg: x_max is less than or equal to x_min for bbox [0.65625    0.70555556 0.65625    0.70555556 1.        ].
# Error during transform on WEB05886.jpg: Expected y_max for bbox [0.35546875 0.98055553 0.390625   1.0013889  1.        ] to be in the range [0.0, 1.0], got 1.0013889074325562.
# Error during transform on WEB06028.jpg: Expected x_max for bbox [0.44637224 0.         1.0031545  0.5431579  0.        ] to be in the range [0.0, 1.0], got 1.0031545162200928.
# Error during transform on WEB06101.jpg: Expected x_max for bbox [0.9252032  0.09       1.003252   0.19666666 1.        ] to be in the range [0.0, 1.0], got 1.0032520294189453.
# Error during transform on WEB06251.jpg: Expected x_max for bbox [0.33548388 0.01694915 1.0016129  0.8644068  0.        ] to be in the range [0.0, 1.0], got 1.001612901687622.
# Error during transform on WEB06363.jpg: Expected y_max for bbox [0.65722656 0.59375    0.99316406 1.0013021  0.        ] to be in the range [0.0, 1.0], got 1.0013021230697632.
# Error during transform on WEB06611.jpg: Expected x_max for bbox [0.634434   0.00833333 1.0011792  0.16666666 0.        ] to be in the range [0.0, 1.0], got 1.0011792182922363.
# Error during transform on WEB06733.jpg: Expected y_max for bbox [0.00625002 0.12083331 0.73828125 1.0013889  0.        ] to be in the range [0.0, 1.0], got 1.0013889074325562.
# Error during transform on WEB06750.jpg: Expected x_max for bbox [0.9140625  0.29027778 1.0007813  0.36527777 1.        ] to be in the range [0.0, 1.0], got 1.0007812976837158.
# Error during transform on WEB06754.jpg: Expected x_max for bbox [0.8109375  0.16527778 1.0015625  0.30833334 0.        ] to be in the range [0.0, 1.0], got 1.001562476158142.
# Error during transform on WEB06900.jpg: x_max is less than or equal to x_min for bbox [0.8539063  0.23333333 0.8539063  0.23333333 1.        ].
# Error during transform on WEB07167.jpg: Expected y_max for bbox [0.19999999 0.21171173 0.99113923 1.0022522  0.        ] to be in the range [0.0, 1.0], got 1.002252221107483.
# Error during transform on WEB07460.jpg: Expected x_max for bbox [0.00357142 0.00919542 1.002381   0.74022985 0.        ] to be in the range [0.0, 1.0], got 1.0023809671401978.
# Error during transform on WEB07714.jpg: Expected y_max for bbox [0.03196348 0.801217   0.24657536 1.0020283  1.        ] to be in the range [0.0, 1.0], got 1.0020283460617065.
# Error during transform on WEB07720.jpg: Expected x_max for bbox [0.15206182 0.01145038 1.0025773  0.88358784 0.        ] to be in the range [0.0, 1.0], got 1.002577304840088.
# Error during transform on WEB07998.jpg: x_max is less than or equal to x_min for bbox [0.646875  0.4715909 0.646875  0.4715909 0.       ].
# Error during transform on WEB08558.jpg: Expected x_min for bbox [-0.03921568  0.00833333  0.9362745   0.57222223  0.        ] to be in the range [0.0, 1.0], got -0.039215683937072754.
# Error during transform on WEB08559.jpg: Expected x_min for bbox [-0.00980392  0.          0.6813725   0.39722222  0.        ] to be in the range [0.0, 1.0], got -0.009803920984268188.
# Error during transform on WEB08632.jpg: Expected y_min for bbox [ 7.8123808e-04 -8.3333254e-03  1.0007813e+00  8.3611113e-01
#   0.0000000e+00] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB08636.jpg: Expected y_min for bbox [ 0.3265625  -0.00833333  0.99375     0.7361111   0.        ] to be in the range [0.0, 1.0], got -0.008333325386047363.
# Error during transform on WEB08643.jpg: Expected x_min for bbox [-0.00624999  0.05555554  0.3375      0.46944445  1.        ] to be in the range [0.0, 1.0], got -0.0062499940395355225.
# Error during transform on WEB08646.jpg: Expected y_min for bbox [ 0.01718751 -0.00277777  0.3828125   0.25833333  0.        ] to be in the range [0.0, 1.0], got -0.002777770161628723.
# Error during transform on WEB08654.jpg: Expected y_max for bbox [0.01406249 0.00138891 0.5015625  1.0013889  0.        ] to be in the range [0.0, 1.0], got 1.0013889074325562.
# Error during transform on WEB08656.jpg: Expected x_max for bbox [0.06372547 0.00833333 1.0392157  0.57222223 0.        ] to be in the range [0.0, 1.0], got 1.0392156839370728.
# Error during transform on WEB08658.jpg: Expected y_min for bbox [ 0.31862745 -0.00555556  1.0098039   0.39722222  0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB08659.jpg: Expected y_min for bbox [ 0.25490198 -0.00277779  1.0245098   0.375       0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB08661.jpg: Expected x_min for bbox [-0.00980392  0.00833333  0.5392157   0.56666666  0.        ] to be in the range [0.0, 1.0], got -0.009803920984268188.
# Error during transform on WEB08669.jpg: Expected x_max for bbox [0.002451   0.00277779 1.002451   0.5277778  0.        ] to be in the range [0.0, 1.0], got 1.002450942993164.
# Error during transform on WEB08673.jpg: Expected y_min for bbox [ 0.01093751 -0.01111111  0.58125     0.8166667   0.        ] to be in the range [0.0, 1.0], got -0.01111111044883728.
# Error during transform on WEB08675.jpg: Expected x_min for bbox [-0.0078125  -0.00277779  0.9921875   0.5083333   0.        ] to be in the range [0.0, 1.0], got -0.0078125.
# Error during transform on WEB08676.jpg: Expected y_min for bbox [ 0.00312501 -0.00555554  1.003125    0.70277774  0.        ] to be in the range [0.0, 1.0], got -0.005555540323257446.
# Error during transform on WEB08677.jpg: Expected y_min for bbox [ 0.01249999 -0.00277779  0.9875      0.5611111   0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB08681.jpg: Expected x_min for bbox [-0.0078125   0.00833334  0.6703125   0.49722224  0.        ] to be in the range [0.0, 1.0], got -0.0078125.
# Error during transform on WEB08683.jpg: Expected x_min for bbox [-0.00234374  0.01944445  0.9976562   0.38055557  0.        ] to be in the range [0.0, 1.0], got -0.0023437440395355225.
# Error during transform on WEB08686.jpg: Expected x_min for bbox [-0.01718751  0.00277777  0.44375     0.425       0.        ] to be in the range [0.0, 1.0], got -0.017187505960464478.
# Error during transform on WEB08687.jpg: Expected y_min for bbox [ 0.2703125  -0.00277779  0.9953125   0.55277777  0.        ] to be in the range [0.0, 1.0], got -0.002777785062789917.
# Error during transform on WEB08696.jpg: Expected y_min for bbox [ 0.00156251 -0.00568181  0.5484375   0.4403409   0.        ] to be in the range [0.0, 1.0], got -0.005681812763214111.
# Error during transform on WEB08698.jpg: Expected x_min for bbox [-0.01406251  0.00284091  0.5078125   0.5056819   0.        ] to be in the range [0.0, 1.0], got -0.014062508940696716.
# Error during transform on WEB08708.jpg: Expected x_min for bbox [-0.01257861 -0.00555556  0.9779874   0.50277776  0.        ] to be in the range [0.0, 1.0], got -0.012578606605529785.
# Error during transform on WEB08711.jpg: Expected x_max for bbox [0.00471699 0.00277776 1.004717   0.6611111  0.        ] to be in the range [0.0, 1.0], got 1.0047169923782349.
# Error during transform on WEB08712.jpg: Expected x_max for bbox [0.00786161 0.         1.0078616  0.69722223 0.        ] to be in the range [0.0, 1.0], got 1.007861614227295.
# Error during transform on WEB08714.jpg: Expected y_min for bbox [ 0.09119499 -0.00277776  1.0267296   0.6388889   0.        ] to be in the range [0.0, 1.0], got -0.0027777552604675293.
# Error during transform on WEB08718.jpg: Expected y_min for bbox [ 0.3390625  -0.00555556  0.6578125   0.42777777  0.        ] to be in the range [0.0, 1.0], got -0.00555555522441864.
# Error during transform on WEB08725.jpg: Expected y_min for bbox [ 0.01499999 -0.03333333  1.015       0.61111116  0.        ] to be in the range [0.0, 1.0], got -0.03333333134651184.
# Error during transform on WEB08727.jpg: Expected y_min for bbox [ 0.00749999 -0.00555554  1.0074999   0.5694444   0.        ] to be in the range [0.0, 1.0], got -0.005555540323257446.
# Error during transform on WEB09163.jpg: Expected y_max for bbox [0.19592875 0.32151902 0.4173028  1.0025316  0.        ] to be in the range [0.0, 1.0], got 1.00253164768219.
# Error during transform on WEB09241.jpg: Expected y_max for bbox [0.5467336  0.28286853 0.919598   1.0398407  1.        ] to be in the range [0.0, 1.0], got 1.0398406982421875.
# Error during transform on WEB09312.jpg: Expected x_max for bbox [0.74777776 0.04347828 1.001111   0.8656126  0.        ] to be in the range [0.0, 1.0], got 1.0011110305786133.
# Error during transform on WEB09339.jpg: Expected x_max for bbox [0.12250003 0.03125    1.005      0.8526786  0.        ] to be in the range [0.0, 1.0], got 1.0049999952316284.
# Error during transform on WEB09346.jpg: Expected y_max for bbox [0.00603867 0.01724136 0.9432367  1.0019157  0.        ] to be in the range [0.0, 1.0], got 1.001915693283081.
# Error during transform on WEB09363.jpg: Expected x_max for bbox [0.06111109 0.09405941 1.0611111  1.0940595  0.        ] to be in the range [0.0, 1.0], got 1.0611110925674438.
# Error during transform on WEB09424.jpg: Expected x_max for bbox [0.01250002 0.08000001 1.005      0.84333336 0.        ] to be in the range [0.0, 1.0], got 1.0049999952316284.

# %%
import shutil
import os
from tqdm import tqdm

# Merge augmented images into original image folder
for f in tqdm(os.listdir(aug_image_dir), desc="Merging images"):
    src = os.path.join(aug_image_dir, f)
    dst = os.path.join(image_dir, f)
    if not os.path.exists(dst):  # Avoid overwriting
        shutil.copy(src, dst)

# Merge augmented labels into original label folder
for f in tqdm(os.listdir(aug_label_dir), desc="Merging labels"):
    src = os.path.join(aug_label_dir, f)
    dst = os.path.join(label_dir, f)
    if not os.path.exists(dst):  # Avoid overwriting
        shutil.copy(src, dst)
# Out:
# Merging images: 100%|███████████████████████████████████████████████████████████| 13898/13898 [01:46<00:00, 130.71it/s]
# Merging labels: 100%|███████████████████████████████████████████████████████████| 13898/13898 [01:02<00:00, 221.53it/s]
